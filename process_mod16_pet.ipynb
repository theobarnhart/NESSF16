# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from osgeo import ogr
from osgeo import gdal
import glob as glob
import os
import ntpath
# %matplotlib inline

# %%
files = glob.glob('./MOD16A2_monthly/MOD16A2_wUS_PET_*.clp.tiff')

# %%
# open one raster to initialize

fl = files[0]

ds = gdal.Open(fl)
ET = np.array(ds.GetRasterBand(1).ReadAsArray())
ET = ET.astype(np.float16)

# clear the fill values
ET[ET>32700] = np.NaN

# remove negative values
ET[ET < 0] = np.NaN

# rescale the data to mm/month
ET *= 0.1

ct = 1

# %%
for fl in files[1:]:
    ds = gdal.Open(fl)
    tmp = np.array(ds.GetRasterBand(1).ReadAsArray())
    tmp = tmp.astype(np.float16)
    # clear the fill values

    tmp[tmp>32700] = np.NaN

    # remove negative values
    tmp[tmp < 0] = np.NaN

    # rescale the data to mm/month
    tmp *= 0.1
    
    ET += tmp
    
    ct += 1

# %%
ET /= ct # compute monthly average
ET *= 12 # compute annual average

# %%
np.savez_compressed('./annual_MOD16PET_wUS.npz',pet = ET)

# %%
ET2 = ET[np.isnan(ET)==0]
plt.hist(ET2,100);

# %%
plt.imshow(ET/1000., cmap = 'inferno_r', vmin=np.nanmin(ET)/1000,vmax=np.nanmax(ET)/1000)
plt.colorbar()

# %%
np.nanmin(ET)
# Out:
# 32.375

# %%
np.nanmax(ET)
# Out:
# 1120.0

# %%
# Out:
# inf
